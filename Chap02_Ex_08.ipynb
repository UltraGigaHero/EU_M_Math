# %% [markdown]
# <a href="https://colab.research.google.com/github/UltraGigaHero/EU_M_Math/blob/main/Chap02_Ex_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import Series,DataFrame
import pandas as pd

attri_datal = {'ID':['1','2','3','4','5'],
               'Sex':['F','F','M',"M","F"],
               'Money':[1000,2000,500,300,700],
               'Name':['Saito','Horie','Kondo','Kawada','Matsubara']}
attri_data_framel = DataFrame(attri_datal)

attri_data_framel.groupby('Sex')['Money'].mean()
# Out:
# Sex
# F    1233.333333
# M     400.000000
# Name: Money, dtype: float64
