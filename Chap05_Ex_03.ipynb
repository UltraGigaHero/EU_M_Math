# %% [markdown]
# <a href="https://colab.research.google.com/github/UltraGigaHero/EU_M_Math/blob/main/Chap05_Ex_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numpy.random as random
import scipy as sp

import matplotlib.pyplot as plt
import matplotlib as mpl

x_array = np.array([1,2,3,4,5])
y_array = np.array([6,7,8,9,10])

cond_data = np.array([False,False,True,True,False])

print(np.where(cond_data,x_array,y_array))
# Out:
# [ 6  7  3  4 10]
