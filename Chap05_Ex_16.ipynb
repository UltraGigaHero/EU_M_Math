# %% [markdown]
# <a href="https://colab.research.google.com/github/UltraGigaHero/EU_M_Math/blob/main/Chap05_Ex_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy import integrate
import math
from numpy import cos

integrate.quad(cos, 0, math.pi)
# Out:
# (4.9225526349740854e-17, 2.2102239425853306e-14)
