# %% [markdown]
# <a href="https://colab.research.google.com/github/UltraGigaHero/EU_M_Math/blob/main/Chap05_Ex_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp

from scipy import integrate
import math

def calc(x):
  return (x+1)**2

integrate.quad(calc, 0, 2)
# Out:
# (8.666666666666668, 9.621932880084691e-14)
