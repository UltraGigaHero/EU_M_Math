# %% [markdown]
# <a href="https://colab.research.google.com/github/UltraGigaHero/EU_M_Math/blob/main/Chap05_Ex_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
from scipy import interpolate

import matplotlib.pyplot as plt

x = np.linspace(0, 10, num = 11, endpoint=True)
y = np.sin(x**2/5.0)

f = interpolate.interp1d(x,y,'linear')

f2 = interpolate.interp1d(x,y,'quadratic')

f3 = interpolate.interp1d(x,y,'cubic')

xnew = np.linspace(0, 10,num=30,endpoint=True)

plt.plot(x, y ,'o', xnew, f(xnew), '-', xnew, f2(xnew), '--', f3(xnew), '--')

plt.legend(['data','linear','quadratic','cubic'], loc='best')
plt.grid(True)
