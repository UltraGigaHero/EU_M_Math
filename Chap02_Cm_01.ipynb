# %% [markdown]
# <a href="https://colab.research.google.com/github/UltraGigaHero/EU_M_Math/blob/main/Chap02_Cm_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

n = 10000

x = np.random.uniform(0.0,1.0,n)

print(x)
# Out:
# [0.48720798 0.01675618 0.57680719 ... 0.92984235 0.29668648 0.14525777]
