# %% [markdown]
# <a href="https://colab.research.google.com/github/UltraGigaHero/EU_M_Math/blob/main/Chap02_Ex_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

x = np.random.normal(100,15,10)
#平均値は100、標準偏差は151

min = x.min()
max = x.max()
total = x.sum()

print(x)
print(min)
print(max)
print(total)
# Out:
# [117.70083181  96.89308805  99.60746388 133.37264926  94.79310639
#   96.71947551  97.43657469 134.56629089  89.4958772   81.27725945]
# 81.27725945296126
# 134.56629088653818
# 1041.8626171411536
