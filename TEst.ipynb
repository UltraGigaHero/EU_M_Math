# %% [markdown]
# <a href="https://colab.research.google.com/github/UltraGigaHero/EU_M_Math/blob/main/TEst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('hellow world!')
# Out:
# hellow world!
