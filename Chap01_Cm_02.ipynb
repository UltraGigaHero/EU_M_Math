# %% [markdown]
# <a href="https://colab.research.google.com/github/UltraGigaHero/EU_M_Math/blob/main/Chap01_Cm_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("nを入力："))
for i in range(3, n):
    judge = True

    for j in range(2, i):
      if i % j == 0:
         judge = False
         break

    if judge:
       print(i)
