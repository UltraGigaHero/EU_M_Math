# %% [markdown]
# <a href="https://colab.research.google.com/github/UltraGigaHero/EU_M_Math/blob/main/Chap05_Ex_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numpy.random as random
import scipy as sp

import matplotlib.pyplot as plt
import matplotlib as mpl

sample_names = np.array(['a','b','c','d','a'])
random.seed(0)
data = random.randn(5,5)

sample_names == 'b'
data[sample_names == 'b']
# Out:
# array([[-0.97727788,  0.95008842, -0.15135721, -0.10321885,  0.4105985 ]])
