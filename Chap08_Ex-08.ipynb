# %% [markdown]
# <a href="https://colab.research.google.com/github/UltraGigaHero/EU_M_Math/blob/main/Chap08_Ex-08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.svm import SVC

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

cancer = load_breast_cancer()

X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, stratify = cancer.target, random_state=0)

model = SVC(kernel = 'rbf', random_state = 0)
model.fit(X_train, y_train)

print('スコア(train):{:.3f}'.format(model.score(X_train, y_train)))
print('スコア(test):{:.3f}'.format(model.score(X_test, y_test)))
# Out:
# スコア(train):0.923
# スコア(test):0.916
